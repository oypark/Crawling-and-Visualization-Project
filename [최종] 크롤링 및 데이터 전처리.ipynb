# %% [markdown]
# # [TEAM 8] 프로젝트 1. 크롤링 및 시각화
#
# ## 1. 크롤링
#
# ### 1) 역할 분배
#
#
# a. **도희** : 드라이브 오픈 - 네이버 열기 - 네이버 검색창 클릭 - 검색어 입력 - Keys.RETURN
#         > 검색어 : ***펜션***, 펜션 추천, 가족 펜션, 키즈 펜션, 노키즈 펜션, 커플 펜션, 독채 펜션, 풀빌라 펜션, 스파 펜션, 복층 펜션, 오션뷰 펜션, 반려견 동반(애견?) 펜션, 신축 펜션)
#
# b. **민재** : 인플루언서 탭 클릭 - if문 블로그 글 날짜(2021년 이후) 확인 - 인플루언서 팬수 및 글 url 가져오기
#
# c. **옥영** : url 열기 - if 네이버 맵 태그 확인 - 블로그제목, 블로그 본문, 펜션이름, 위도, 경도  가져오기
#
# * 크롤링 해온 데이터 저장 (dataframe)
#
#     | 검색어 | 업로드날짜 | 블로그url | 인플루언서팬수 | 블로그제목 | 펜션이름 | 블로그본문 | 위도 | 경도 |
#     | --- | --- | --- | --- | --- | --- | --- | --- | --- |
#     |  |  |  |  |  |  |  |  |  |
#     |  |  |  |  |  |  |  |  |  |

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from datetime import datetime, timedelta
import time
import pandas as pd
import numpy as np
import json
import re
import seaborn as sns
import matplotlib.pyplot as plt
import folium
import geopandas as gpd
from folium.plugins import MarkerCluster
# Out:
# C:\Users\dhfps\anaconda3\envs\geo\lib\site-packages\pyproj\__init__.py:91: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_LIB or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))

# %% [markdown]
# ### 1) 도희
#
# * 네이버 열고 검색어 입력 후 검색하기

# %%
search_word = input("검색어를 입력하세요:")

driver = webdriver.Chrome('./chromedriver')
driver.get("https://www.naver.com/")
driver.implicitly_wait(1)

elem = driver.find_element_by_class_name("input_text")

elem.send_keys(search_word)
elem.send_keys(Keys.RETURN)

driver.implicitly_wait(2)
# Out:
# 검색어를 입력하세요:풀빌라 펜션
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_6736/741101771.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_6736/741101771.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem = driver.find_element_by_class_name("input_text")

# %% [markdown]
# ### 2) 민재
#
# * 인플루언서 버튼 클릭

# %%
a = driver.find_element(By.CSS_SELECTOR, "li.menu:nth-child(5) > a")
b = driver.find_element(By.CSS_SELECTOR, "li.menu:nth-child(7) > a")

print(a.text)

if a.text == "인플루언서NEW":
    a.click()
else:
    b.click()
    
time.sleep(1)
# Out:
# 인플루언서NEW

# %% [markdown]
# * 스크롤 제일 아래로 내리기

# %%
last_height = driver.execute_script("return document.documentElement.scrollHeight")

while True:

    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    time.sleep(2)

    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:    #last_height에 원하는 수치 입력
        break
    last_height = new_height
    

driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

# %% [markdown]
# * 인플루언서 탭에 올라와 있는 게시글 url, 업로드 날짜, 블로거 이름, 팬 수 크롤링

# %%
## 문자열을 날짜로 변환하는 함수

def str2date(date_str):

    if date_str[1:] == "일 전":    #일주일 이내 등록된 게시글
        date = datetime.today() - timedelta(days=int(date_str[0]))   #업로드 날짜 계산
        return date

    elif (date_str == "어제") or (date_str[2:] == "시간 전"):
        date = datetime.today() - timedelta(days=1)   #업로드 날짜 계산
        return date
    
    elif (date_str[1:] == "시간 전") or (date_str[1:] == "분전") or (date_str[2:] == "분전"):
        date = datetime.today()
        return date
    
    else:
        date_str = date_str.replace(".","-")[:-1]   #"%Y-%m-%d" 형식으로 변환
        date = datetime.strptime(date_str,"%Y-%m-%d")   #문자열을 날짜 형식으로 변환
        return date
    
    ## 함수 돌아가면 datetime 형식 날짜 리턴



### 크롤링 코드 ###

dates = []
bloger_names = []
fan_counts = []
urls = []

## 업로드 날짜
span_dates = driver.find_elements(By.CSS_SELECTOR, "div.detail_box._cross_trigger span.date")

for each in span_dates:
    date_str = each.text      #텍스트만 가져오기
    result_date = str2date(date_str)   #문자열인 date를 넣으면 datetime 형식으로 변환하는 함수 사용
    dates.append(result_date)

## 블로거 이름
names = driver.find_elements(By.CSS_SELECTOR, "div.user_box_inner a.name.elss")

for each in names:

    name = each.text
    bloger_names.append(name)
    
## 팬 수
fans = driver.find_elements(By.CSS_SELECTOR, "div.user_box_inner span._fan_count")

for each in fans:
    fan = each.text
    fan_counts.append(fan)

## 블로그 url
a_links = driver.find_elements(By.CSS_SELECTOR, "div.dsc_area > a.name_link")

for each in a_links:
    url = each.get_attribute("href")
    urls.append(url)


print(len(dates))
print(len(bloger_names))
print(len(fan_counts))
print(len(urls))
# Out:
# 500
# 508
# 508
# 508

# %% [markdown]
# * (선택적) 날짜 이외의 정보들 개수 500개 초과시 아래 셀 실행

# %%
## 500개 초과된 변수가 존재한다면
## 앞쪽에서 부터 500개로 맞춰서 슬라이싱 후 데이터프레임 생성

if len(bloger_names) > 500:
    bloger_names = bloger_names[len(bloger_names)-500:]
    
if len(fan_counts) > 500:
    fan_counts = fan_counts[len(fan_counts)-500:]
    
if len(urls) > 500:
    urls = urls[len(urls)-500:]
    
    #개수 수정안해도 되도록 수정함(옥영)

# %% [markdown]
# * 팬 수 숫자로 수정하기

# %%
fans = []

for i in range(len(fan_counts)):
    count = re.sub("[만]?\+","000",fan_counts[i])
    count = int(re.sub("[.,]","",count))
    fans.append(count)

# %% [markdown]
# * 가져온 블로그 정보 데이터프레임으로 변환

# %%
search_blogs = pd.DataFrame()

search_blogs['dates'] = dates
search_blogs['bloger_names'] = bloger_names
search_blogs['fans'] = fans
search_blogs['urls'] = urls

search_blogs.head()
# Out:
#        dates bloger_names   fans  \
# 0 2021-12-27          열씨미  14000
# 1 2021-12-24         망고요정  13000
# 2 2021-12-23           유에   1000
# 3 2021-12-02         일상탈출  13000
# 4 2021-11-21          에릭샘  11000
#
#                                                 urls
# 0  https://in.naver.com/jbm993/contents/internal/...
# 1  https://in.naver.com/mango/contents/internal/3...
# 2  https://in.naver.com/rafiuta/contents/internal...
# 3  https://in.naver.com/tcacyc/contents/internal/...
# 4  https://in.naver.com/usgreen99/contents/intern...

# %% [markdown]
# * csv 파일로 저장

# %%
## search_blogs csv 파일로 저장
search_blogs.to_csv('search_blogs_pool.csv', header = False, index = False, encoding='euc-kr')

#검색어 확인 후 search_blogs_뒷부분 영어로 추가해주세요!!★

# %%
driver.close()   #크롬 닫기

# %% [markdown]
# ## 3) 옥영
#
# * 전체 코드

# %%
titles = []
main_contents = []
place_ids = []
place_names = []
place_addrs = []
place_tels = []
lats = []
lons = []
urls = []
blog_urls = []


## 크롬 숨겨서 크롤링하는 옵션
options = webdriver.ChromeOptions()
options.add_argument("headless")
options.add_argument("--no--sandbox")
options.add_argument("disable-dev-shm-usage")


### 크롤링 코드 ###

for url in range(len(search_blogs)):
    
    ## 블로그 url 열기
    driver = webdriver.Chrome('.\chromedriver', chrome_options = options)
    driver.get(search_blogs['urls'][url])
    time.sleep(1)
    
    ## 블로그인지 url 받아와서 확인
    current_url = driver.current_url
    
    if current_url[:23] == "https://blog.naver.com/":
    
        ## 본문 내용이 있는 iframe(mainFrame)으로 들어가기
        driver.switch_to.frame("mainFrame")
        
        ## map_info 있는지 확인
        check_elements = driver.find_elements(By.CSS_SELECTOR, "div.se-module > a.se-map-info")
        
        ## map_info 있으면 블로그 글 제목, 본문 내용, 펜션 이름, 위도, 경도 데이터 저장
        if len(check_elements) != 0:
            
            ## map_info에 네이버 맵 정보 가져오기
            map_info = driver.find_element(By.CSS_SELECTOR, "div.se-module > a.se-map-info")
            map_data = map_info.get_attribute("data-linkdata")
            map_dict = json.loads(map_data)   # str 형태의 map_data를 dict 형태로 변환
            time.sleep(1)

            ## 블로그 글 제목 가져오기
            title = driver.find_element(By.CSS_SELECTOR, "div.pcol1").text
            titles.append(title)
            print(title)

            ## 블로그 본문 내용 가져오기
            contents = driver.find_elements(By.CSS_SELECTOR, "div.se-component.se-text.se-l-default")
            texts = []
            for each in contents:
                texts.append(each.text)    #contents 안에 있는 text만 가져와서 저장
            text = " ".join(texts)    #list 요소로 저장된 문장들 하나로 이어붙이기
            main_contents.append(text)

            ## 펜션 정보 가져오기
            place_ids.append(map_dict['placeId'])
            place_names.append(map_dict['name'])
            place_addrs.append(map_dict['address'])
            place_tels.append(map_dict['tel'])
            lats.append(map_dict['latitude'])
            lons.append(map_dict['longitude'])
            
            ## url 저장하기
            url = search_blogs['urls'][url]
            urls.append(url)
            current_url = driver.current_url
            blog_urls.append(current_url)
            
            ## 웹 드라이버 종료
            driver.close()

        else:
            driver.close()
    else:
        driver.close()
# Out:
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_6736/2837098447.py:22: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('.\chromedriver', chrome_options = options)
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_6736/2837098447.py:22: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('.\chromedriver', chrome_options = options)
# 경남 펜션 오션뷰 숙소 사천 풀빌라 독채 펜션
# 부산 펜션 송정해수욕장 풀빌라 호텔 후기
# 남해 숙소 추천 감성 오션뷰 수영장 노천탕 남해 풀빌라 펜션 웨이포인트풀빌라
# 경남 펜션 감성 넘치는 사천 풀빌라 독채펜션
# 대부도 풀빌라 디디모스 키즈 펜션 리얼 후기
# 여수 독채 풀빌라 펜션 온수풀 수영장
# 국내 감성숙소 충북 제천 풀빌라 펜션 수페23 숙박 후기
# 충청도 신상 숙소 독채 풀빌라 모음 ; 아산 스테이느느루, 청주 휘게, 공주 스테이오안, 옥천 시작에머물다, 신축 감성 펜션
# 영덕 펜션 하저스테이 :: 포항 근교 독채 풀빌라 가족여행
# 포항 풀빌라 펜션 하루 / 오션뷰 수영장, 스파 신축 숙소 ♥
# 남해 신축 감성숙소 디풀빌라 펜션 , 동남아 느낌 낭낭 🌴
# 경남 펜션 사천 풀빌라 펜션 시엘로리조트
# 울진숙소 추천 울진 풀빌라 펜션 산포리펜션에서 제대로 오션뷰펜션
# 오션뷰 풀빌라 경주 펜션 추천 감포 숙소 샵앤플랫
# 전남 펜션 중 목포에서 가까운 무안 풀빌라 애모시옹
# [여수여행] 여수 숙소 추천, 여수 블루망고 풀빌라 펜션
# [가평숙소] 가평 풀빌라 펜션 온수풀 단독펜션 V528 리얼후기
# 거제도 펜션 프라이빗상상 풀빌라
# 경주 오푸스11 온수 풀파티 수영장 대가족 풀빌라펜션 추천 (겨울에 가볼만한곳 애견동반 스파)
# 가평 키즈펜션 수영장 풀빌라 펜션..
# 가평풀빌라 펜션 V528 가족 여행지로 추천해요!
# 거제도 펜션 풀빌라 바다뷰는 덤~
# 여수 펜션 온수 풀빌라 리조트 슈가브리움
# 양평 숙소, 수영장 있는 커플 감성 풀빌라 펜션 그랑아치
# 제주도 풀빌라펜션 추천/ 오션브릭스, 산방산 아래의 아름다운 바다와 만나는 멋진 뷰
# 거제도 키즈 풀빌라펜션 모든 것이 만족에 만족
# 여수 독채 펜션 풀빌라 비고 리조트 황홀 오션뷰
# 강원도 춘천 유유자적 수영장 강뷰 풀빌라 펜션
# 경주 독채풀빌라 온수풀 펜션 스테이 마당 숙소 후기
# 거제도 숙소 흑진주마리나 리조트 풀빌라 펜션
# 거제 풀빌라 펜션 호텔상상 지심도 품은 오션뷰
# 순천 풀빌라 펜션 로얄맨션 감동 포인트!
# 경남 독채 풀빌라 레인보우 키즈 펜션 다녀왔어요!
# 경주키즈풀빌라펜션 또가고싶은 플렉스풀빌라
# 경남 가볼만한곳 사천 비토섬 비토애풀빌라펜션 오션뷰
# [통영 풀빌라 펜션] 해지음풀빌라 - 프라이빗한 개별수영장에서 오션뷰 보면서 호캉스하기 좋은 통영 숙소
# 제주 풀빌라 독채 펜션 스테이데이앤데이 신축 숙소 추천
# 가평 풀빌라 펜션 V528 여행의 편안함, 즐거움이 함께하는 계곡펜션
# 여수 풀빌라 온수풀 펜션 블루망고 인피니티풀 프라이빗
# 학동몽돌해수욕장 근처 거제도 풀빌라 가족펜션
# 포항 풀빌라 마치블루 럭셔리한 감성의 오션뷰 펜션
# 양평 풀빌라 펜션 감성숙소 그랑아치 / 바베큐와 수영장까지 완벽해 ♥
# 영덕 풀빌라 프라이빗한 전용 오션뷰펜션
# 여수 풀빌라 펜션 프라이빗 온수풀 수영장 있는 여수리조트 블루망고
# 여수 펜션, 블루망고 풀빌라 앤 리조트 키즈룸
# 강릉 여행, 강문해변 풀빌라 스카리아에서
# 남이섬 펜션 스파 실내수영장도 있다~ 리버노스풀빌라
# 여수 펜션 블루망고 풀빌라 앤 리조트 온수풀 & 조식 리뷰
# 가평풀빌라펜션 호캉스 안부러움!
# 애견동반 양평풀빌라 펜션 : 풀스테이 조이풀빌라
# 여수슈가브리움 오션뷰 감성숙소 풀빌라펜션
# 생일기념여행 : 가평 키즈풀빌라펜션 미즈베베 GO!
# 강원도 횡성 숙소 추천 : 수영장과 제트스파를 갖춘 독채 펜션 , 엔제이풀빌라
# 울산 풀빌라 까르마레 펜션 숙소로 최고였죠
# 대부도 펜션 블루블랑 독채 풀빌라 사계절 온수풀
# 경북 포항 메르송 풀앤스파 : 전망 좋은 오션뷰 럭셔리 풀빌라 펜션
# 대부도 풀빌라 세비아 키즈풀빌라 가족 독채펜션 후기 추천
# 경주 숙소 추천, 감포 오션뷰 풀빌라 샵앤플렛 후기
# 강원도 홍천 풀빌라펜션 더체어 독채라 프라이빗해
# [여행] 장성 ➋ 이번 여정 힐링의 꽃 담양펜션 ○ 담양 풀빌라펜션 더힐링나인
# 거제도 풀빌라 펜션 거제 오션뷰 숙소
# 울진가볼만한곳♥울진여행♥울진후포항♡등기산스카이워크♥울진숙소☆울진펜션 ☆울진풀빌라는 여기 추천 풀빌라 블루아라 완전좋아여
# 영덕 오션뷰 풀빌라 펜션  시포트리조트
# 남해 감성숙소 풀빌라 더뷰 분위기에 반해버린 독채 펜션
# 제주도 수영장 펜션 / 더휴 풀빌라 ft. 실내온수풀 & 자쿠지
# 밀양 키즈풀빌라 객실2개 독채 가족 온수 수영장 아주르 펜션
# 대부도 독채펜션 :: 반려견 동반가능 풀빌라
# 남해 풀빌라 펜션 더뷰1151 프라이빗 감성 숙소 오션뷰에 반하다!
# 포항여행 숙소: 오션뷰 풀빌라펜션 메르송풀앤스파
# 울진 후포항 오션뷰 풀빌라 펜션 프렌치페이퍼 아버지와 둘이서 1박 2일
# 1박 2일 강원도 춘천여행 감성숙소 수영장 있는 풀빌라 독채 펜션
# 여수 펜션 커플풀빌라 오션뷰 리조트로 좋아요
# 영덕 펜션 광활한 경북 바다가 보이는 대구 근교 영덕 풀빌라 숙소
# 강원도 홍천 풀빌라 펜션 독채 수영장까지 완벽한 숙소 더체어
# 제주 까르마풀빌라펜션 제주도풀빌라 독채풀빌라
# 가평 풀빌라 펜션 브룩5(Brook5) 완벽하게 하루 즐기기
# 가평풀빌라펜션 V528 에서 커플여행 추억만들기
# 안면도 풀빌라 수영장펜션(지중해아침펜션)서해안 휴양지 추천
# 서울 근교 풀빌라 펜션 리버노스 1박 2일 가족여행 추천 숙소
# 경주 풀빌라 바다 가득 감성 사진 찍기 좋은 스파 펜션
# 경주펜션 이국적인 분위기의 오푸스11 풀빌라
# 춘천 풀빌라 펜션 v528, 절경 아래의 독채 커플풀빌라
# 여수 하이클라스153 풀빌라펜션 도심속 무릉도원
# 제주도 숙소 풀빌라 펜션 풀스테이 함덕 신혼여행 다녀왔어요
# 포근했던 경주 숙소 풀빌라 펜션 더마린
# [공지] 포항 오션뷰 펜션 온수 풀빌라 즐길수있는 하루풀빌라
# 나만의 온수 풀빌라 펜션 best 3 또 가고파
# 가평풀빌라 리버노스풀빌라 펜션 가평여행하기 좋은 남이섬 숙소
# 삼척 비치힐풀빌라 스파펜션 오션뷰가 최고
# 가평 펜션 리버노스 프라이빗했던 풀빌라
# 대부도 펜션 온수풀빌라 티앤지펜션
# 여수 펜션, 블루망고 풀빌라 여수 커플여행 리조트 추천
# 포항 그랑모던풀빌라 프라이빗한 개별수영장 #가족여행
# 제주도 가족펜션 / 동상이몽에 나온 독채풀빌라 민준채
# 충북 제천 신축 풀빌라 펜션, 수페23
# 통영 바다가 보이는 풀빌라 펜션추천 글로우펜션
# 가평 리버노스 풀빌라 펜션 🏊 프라이빗 수영장 온수풀에서 물놀이
# 전남여수풀빌라, 뷰좋고 스파까지 있는 블루망고풀빌라펜션
# 경남합천풀빌라펜션/ 독채수영장_빌라트 풀빌라
# 거제숙소 거가대교 뷰가 아름다운 거제도풀빌라펜션 (비엘펜션)
# 여수 펜션 이국적인 분위기 오션뷰 풀빌라 슈가브리움
# 힐링하기 좋은 가평풀빌라 귀족펜션
# 경북 울진 풀빌라펜션 라메르 오션뷰 풀캉스 (애견 동반 숙소)
# 제주 펜션추천 풀스토리 키즈풀빌라펜션 아이를 위한 최고의 숙소
# [경주 풀빌라 펜션] 최고의 오션뷰 숙소 추천 (스톤앤비치 풀빌라 : 감포 경주)
# 대부도 독채펜션 단체 풀빌라 고래한마리277
# 국내풀빌라 펜션 강원도 홍천 헤리티스 풀빌라 숙박후기
# 제주도 온수풀 풀빌라펜션 대정시크릿풀빌라
# 경주 키즈 펜션  안하우스 풀빌라 에서 즐거운 하루
# 여수 풀빌라 펜션 디마레 바다보며 꿀휴식
# 제주풀빌라펜션 제주까르마 공항근처 허니문으로도 좋은 숙소!
# 가평 키즈펜션, 시설 좋았던 포천 풀빌라
# 제주도 풀빌라 독채, 럭셔리 펜션 추천! 바베큐장부터 온수풀까지
# 가평 키즈풀빌라 펜션 온수풀 물놀이 즐겼어
# 경주펜션 더마린 풀빌라
# 경주키즈펜션 라파미키즈풀빌라 또가고픈곳
# 여수 풀빌라 펜션 그리다리조트 가족 안성맞춤
# 경주 키즈 풀빌라 벤투스 펜션 즐거운 하루밤
# 경기도 안산  가족 풀빌라 독채펜션 온수 수영장 오션스테이
# 가평풀빌라 독채로 쓰는 수영장, 풀빌라펜션
# 독채풀빌라여서 좋았던 제주도 펜션
# 영덕 여행 #1. 장사해수욕장, 영덕오션뷰펜션 | 엑시트 풀빌라
# 경주오션뷰펜션 [샵앤플렛풀빌라]-온수풀, 스파, 천국의계단 후기
# 경주 펜션 샵앤플랫 풀빌라에서 호캉스해요
# 남해 풀빌라펜션 오션뷰 완전 찐이야~
# 영광 신축 풀빌라펜션 삿포로 같았던 " 선셋777 " 영광 펜션 추천
# 경주 풀빌라 엘라포니시 펜션 ! 인피니티풀 인생샷 각 ♥
# 남해 여행_남해 품다 풀빌라 리조트_아이들과 가볼만한 남해 펜션_4월 남해 여행_다랭이마을_두모마을
# 산청 펜션 진주 파티룸으로 사용하기 좋은 풀빌라 독채펜션
# [담양 더힐링나인] 담양 수영장 펜션 추천, 풀빌라에서 즐긴 여름 휴가
# 거제 펜션 뷰가 좋고 안락했던 몽돌해변 풀빌라
# 강원도 속초 펜션, 수영장과 스파까지 따봉 오션뷰 가족풀빌라 숙소
# 동해펜션 삼척비치힐풀빌라.. 바다위에 눕다
# 제주도 풀빌라 단독 온수풀 수영장까지 짱인 코롱코롱 펜션!
# [미원] 청주 풀빌라 펜션 추천, '더리버에스 풀빌라' : 이보다 더 자세할 수 없는 Real한 숙박 후기, 풀 사이드 자쿠지
# 포항풀빌라펜션 오션뷰 제트스파 노래방까지 가성비좋은 포항숙소 0.1풀빌라펜션
# 최고였던 제주도 풀빌라 펜션, 제주 올리브 스파 앤 풀빌라
# 합천 여행 :: 합천 풀빌라 펜션 _ 더 일리있는 풀빌라 ( 내돈내산솔직후기 )
# 거제 풀빌라 미스터준/즐거운 일상 탈출, 거제로 간다! 거제도가족펜션 & 거제스파펜션에서, 1박 2일 ♥
# 가평풀빌라 좋았던 스파 럭셔리한 릴리브 펜션
# 강릉 풀빌라 펜션 라미아까사 똑 소리나는가격으로!
# 대부도여행 _  실내수영장 풀빌라 독채펜션 더머뭄
# 경주펜션 더마린 풀빌라 행복했던 펜캉스 우정여행
# 가평 키즈풀빌라펜션 밤비니 신축이라 깔끔해요
#  리버노스풀빌라 가평 가족여행 프라이빗하게 누리기~
# 강원도 풀빌라 펜션 이용 후기 ! 별이 너무나도 잘보여서 별빛 가득한 강원도 독채 풀빌라 펜션 정선 드위트리펜션
# 경주 감포 펜션 풀빌라 엘라포니시 커플여행 무야호~
# 밀양 아주르풀빌라, 온수풀 가능한 밀양 신축 풀빌라 펜션
# 경주 온수풀빌라 가족펜션 나의 봄 펜션
# [경기도 양평 독채 풀빌라] 합리적 가격의 미온수 야외 수영장 <제나하우스>
# 거제도 펜션 1박2일 여행, 거제 프래밀리 풀빌라 숙소
# 제주 키즈풀빌라 독채펜션 나무와아이에서 주말 제대로 즐기기
# 가평 펜션/풀빌라 인피니티풀 까사32 후기
# [합천여행숙박] 합천호 뷰, 그림 같은 전망 합천'일리 있는 펜션 풀빌라'
# 남해 펜션 바다가 보이는 수영장
# 경북 안동 더담다 키즈 펜션, 더담다 카트 (육아맘 추천 숙소, 코로나 어린이 놀거리, 대구근교 가족여행, 육아 정보, 인스타 감성, 깔끔 청결, 풀빌라)
# 전라도 여수 풀빌라 슈가브리움 미우새 리조트 스윗해
# 가평 애견풀빌라펜션 가평 애견펜션 스톤애견풀빌라펜션 히노끼룸 내 돈 내고 사용한 장단점 솔직후기
# 제주독채풀빌라 속 스파 디오션펜션 가성비 제주애월숙소
# 풀빌라/울산클럽33풀빌라/울산펜션/개별수영장펜션/펜션추천
# 남해 오션뷰 풀빌라 감성숙소 스테이숨, 개별 수영장에 스파까지 갓벽해!(S4 후기)
# 여수 키즈 풀빌라와 카페를 즐길 수 있는 하이클래스 153 리조트
# 회사 단체워크샵장소 추천 양평 포레스트펜션 후기
# 경주 풀빌라 오션뷰풀빌라는 샵앤플렛
# 수영장 있는 양평펜션 블루힐 스파는 덤
# 가평풀빌라 추천, 완벽한 북한강뷰 호텔스위티안
# 경주 펜션 감성 숙소로 핫한 오푸스11풀빌라 후기
# 무주 펜션 리조트 근처 모던하고 다양한 무주 풀빌라
# 포항 펜션 호리존풀빌라, 오션뷰 풀빌라 숙소라 좋다
# 거제도 펜션 풀빌라 감성 숙소
# 대구 키즈풀빌라 펜션 - 폴앤풀 아이와 가기좋은 대구 숙소예요
# 가평 나나 키즈풀빌라펜션
# 경주 풀빌라펜션 레이크뷰 몽환적인 물안개
# 포항 오션뷰 펜션, 데이토나 풀빌라 온수풀 수영장 놀고 바베큐 먹고!
# 거제 펜션 오션뷰 국내 럭셔리 풀빌라 펜션
# 거제도 펜션 오션뷰 프라이빗 풀빌라
# 포항 풀빌라 펜션 오션뷰를 바라보는 더이스트
# 서울 근교 여행 양평 책속에풍덩 숙소 / 자쿠지, 불멍 독채 풀빌라 펜션 ♥
# 경주 누아르블랑, 실내외 수영장 있는 온수풀빌라 펜션
# 경주 풀빌라 키즈펜션추천 하는 수영장 펜션 오푸스11,애들데리고갈만한곳
# 여수 펜션 커플풀빌라 쇼윈도 촬영지 숙소 추천
# 복층 대부도 키즈풀빌라펜션 바베큐장 온수풀장있네~
# 전남펜션 무안 풀빌라 애모시옹 오션뷰 가족 키즈 온수 수영장
# 포항풀빌라 별 보며 힐링하는 190워터프런트 펜션
# 거제도 펜션 바다뷰 멋진 풀빌라
# 경주 호텔 엘라포니시 풀빌라 펜션에서 즐긴 호캉스
# 경주 독채 풀빌라 펜션 <국화맨숀> 수영장 숙소 추천
# 강릉 풀빌라 키즈펜션 온수수영장 펜트하우스 풀빌라
# 키즈펜션추천 :)개별온수수영장 안면도 태안 유키즈풀빌라 독채
# 경남 거제 칠천도 가족 단체 키즈 스파 풀빌라 펜션 여기다!
# 울산 풀빌라 펜션, 히든베이
# 경주 펜션 엘라포니시 풀빌라 퍼펙트
# 청도 숙소 까사로마  풀빌라펜션 후기
# 경주 풀빌라 숙소 추천
# [포항여행] 포항 숙소 추천, 포항 풀빌라 펜션 하루풀빌라
# 경주 펜션 오푸스11 호수뷰 온수풀 풀빌라
# 거제도 펜션 풀빌라 프라이빗 한 1박 2일
# 대부도 펜션 모두 만족한 키즈풀빌라 또가자
# 여수키즈풀빌라 안녕아이들 역대급 키즈독채펜션 온수풀 아이와가볼만한곳
# 경주 펜션 : 가성비 끝판왕 헤이미쉬 풀빌라
# [공지] 포항펜션 데이토나 풀빌라 : 아이와 가기 좋은 포항풀빌라
# 제주 서쪽 숙소 스테이겨를 펜캉스하기 좋은 한림독채풀빌라 펜션
# 남해 풀빌라 독채 펜션 감성 가득한 오션뷰 숙소 추천
# 전남 담양 더설렘풀빌라 독채펜션 실내온수수영장
# 신축 경주 키즈 풀빌라 펜션 진심 베스트 ♪
# 키즈펜션추천 경주 실내수영장 하늘채 키즈 풀빌라
# 기장 오션뷰 풀빌라 씨앤트리펜션
# 남해풀빌라펜션 사우스코스트 A101 수영장 프라이빗풀에서 힐링
# 가평키즈풀빌라 실내 온수풀에서 힐링하기 미쉘키즈풀빌라펜션
# 수페23 제천여행 가시는 분들께 강추드리는 청풍호 제천펜션 온수풀빌라 단양펜션
# 거제 키즈풀빌라 키즈펜션 거제도 온수펜션
# 강원도 펜션 춘천가볼만한곳 춘천숙소 | 춘천풀빌라 V528 집다리골자연휴양림 | 춘천1박2일
# 포항 오션뷰 펜션 데이토나 풀빌라 인피니티풀 이쁜곳
# 가평키즈풀빌라 가성비 좋은 키즈펜션 추천 아이스타키즈풀빌라
# 거제도 가족 펜션 레인보우 키즈풀빌라펜션 (곳간상점)
# 경주 풀빌라 신축 독채펜션 퍼즈빌 A타입 솔직후기
# 여수 풀빌라 펜션 <여수 하월> 온수풀 자쿠지 감성 숙소
# 경남 거제 칠천도 숙소 가족 단체 스파 키즈 온수 풀빌라 펜션
# 잠깨고키즈풀빌라 가성비최고 가평키즈펜션
# 안동 풀빌라펜션 더스터닝 솔직히!
# 가평 키즈펜션 키즈풀빌라 실내수영장 똭~
# 가평풀빌라펜션 릴리브, 온수풀에 바베큐 끝판왕
# 가평 키즈풀빌라펜션ㅣ 바니힐키즈풀빌라 402호 리얼 후기♡
# 가평키즈풀빌라 미즈베베 온수풀 아기랑 갈만한곳 키즈펜션추천
# 거제 룰루랄라 키즈풀빌라 펜션 + 사진 찍기 좋은 동부저수지
# 대부도 키즈풀빌라 라온 신축 숙소 ; 서울근교 온수 실내수영장 펜션, 안산 대부도여행 갈만한곳
# 전라남도 담양 독채 풀빌라 애견펜션 '구르미펜션'
# 대부도 갈만한곳 키즈 풀빌라 펜션 독채 방4개 실내 온수수영장 노래방 있는 쿠키앤제이
# 남해 가볼만한곳 남해 독일마을 외 남해가족펜션
# 거제도 오션뷰 가족 펜션 레인보우 키즈 풀빌라 에서 즐기는 휴식
# 거제 풀빌라펜션 프라이빗상상 온수풀 일출명소
# 거제 펜션 알차게 즐긴 풀빌라
# 통영풀빌라 : 시에나 리조트를 본뜬 프라이빗 오션뷰 수영장 온수풀빌라 펜션
# 아기랑 같이가요, 제주도 서쪽 풀빌라 가족숙소 * 애월로와 키즈펜션
# 밀양 독채 펜션 풀빌라 세인트354  최고의 숙소였어요.
# 경주키즈펜션 라파미키즈풀빌라 온수풀 무료 신축
# 제주도 펜션 가족 숙소로 좋았던 제주 독채 풀빌라
# 태안 풀빌라 | 엘플레이트, 인생 펜션 찾았어요.
# 울산풀빌라 울산오션뷰와 수영장을 한번에 울산펜션 히든베이풀빌라
#  경주 펜션 더마린풀빌라 바다뷰 스파펜션
# 포항 풀빌라 데이토나 펜션 오션뷰 인피니티풀 대박 이쁜곳
# 거제단독펜션 레인보우키즈풀빌라 노천탕에서 힐링!
# 가평 키즈풀빌라 펜션 즐거웠던 숙소
# 포항펜션 데이토나 풀빌라 프라이빗하게 즐긴 오션뷰 숙소 후기
# 이국적인 느낌이 가득한 파주 풀빌라 펜션  중휴림
# 대부도 풀빌라 방3개 온수풀장 키즈들도 환호했던 펜션
# 청도 굿스파 키즈 풀빌라 펜션 추천 알차게 즐기고 옴
# 안산 대부도 여행  신축 풀빌라 키즈 펜션 바다 숙소
# 전남 풀빌라 펜션, 애모시옹 무안! 최고의 여행지
# 밀양풀빌라 독채펜션 신축 4개동 온수수영장 있는 세인트354
# 포항 풀빌라펜션 추천 : 네이처풀빌라 301호에서 프라이빗 온수풀과 스파즐기기
# 경주 키즈풀빌라 펜션 안하우스 아이 생일기념 다녀온 후기
# 경주풀빌라펜션 인생샷 여기있다 오션뷰 루나힐풀빌라
# 경주 감포 낚시, 일출 보기 좋은 동해바다 뷰 숙소 feat. 신축-더 풀빌라 펜션
# 홍천 풀빌라펜션 우노하우스 따뜻하고 조용한 곳
# 제주 온수풀 펜션 제주도 판포홈치 키즈풀빌라
# 경주풀빌라 감포 이오스풀빌라AD 펜션
# 통영 풀빌라 해지음펜션 프라이빗한 온수풀
# 여수 풀빌라 독채 포트240, 프라이빗한 돌산 펜션 추천
# 내가 가려고 모아두는 감성 숙소 LIST -) 전국 숙소_풀빌라편 2 (소월스테이, 디풀빌라, 라이엔네 풀빌라 스테이)
# 보령풀빌라 시스케이프 무창포펜션 다녀왔어요
# 제주도 온수풀 제주도 가족펜션 키즈풀빌라 JB풀빌라
# 경주 키즈풀빌라펜션 까사폴라리스 아이들의 천국!
# 경주독채펜션 경주신상풀빌라 누아르블랑 가족여행 커플여행으로 딱입니다
# 경주 오푸스11 풀빌라 펜션 숙박 후기!
# 거제도 가족펜션 추천 레인보우키즈풀빌라펜션 바베큐파티 /곳간상점 (ft.일출명소)
# 여수 키즈풀빌라 아기랑 갈만한 곳 추천, 자리움 풀빌라 독채 키즈펜션
# 가평 '리버하임' | 프라이빗한 독채 풀빌라에서 친구들과 파티
# 전라도 아기랑갈만한곳 여수 키즈풀빌라 펜션 추천
# 거제도펜션 거제 룰루랄라 키즈풀빌라 뷰도 좋아
# 가평 키즈펜션 추천 아기랑 루미나리에 풀빌라귀족펜션
# 아이와함께 어른들도 즐기자!!ㅋㅋㅋㅋ 가평 남이섬 풀빌라펜션 리버노스
# 경주 키즈 풀빌라 독채 펜션 마카롱 실내수영장과 마당을 갖춘 신축 펜션
# 담양 펜션 사계절 온수풀 즐기는 독채 풀빌라 더힐링나인
# 포항펜션 데이토나 풀빌라 역대급 오션뷰 숙소
# 대부도 키즈 풀빌라 펜션 포함 대부도 여행코스
# 전남 담양 애견동반풀빌라 구르미펜션 너무 행복했던 여행
# 여수키즈펜션 독채로 즐기는 유키즈풀빌라
# 경주키즈풀빌라 휴휴키즈펜션 feat. 주간생일
# [대부도 블루블랑] 경기도 독채 키즈풀빌라 _ 서울근교 대형 온수수영장 펜션
# 온수수영장펜션 하늘호수키즈풀빌라 무료조식
# 노는언니2 폭포리아 풀빌라펜션에서 김장김치대결,김성연 챔피온로고후드티,신수지우승,한유미
# 남이섬 풀빌라 가평여행, 예쁜 복층인테리어 리버노스 가평 펜션
# 경주 풀빌라 독채 수영장 펜션 호플리
# 아쉬운 여수 오션뷰 숙소 : 블루망고 풀빌라 리조트 수영장 펜션
# 영덕 독채펜션 하저스테이
# 여수 숙소 추천 슈가브리움 리조트 여수 수영장 펜션 풀빌라
# 경주독채펜션 신축 풀빌라 누아르블랑
# 경남 해돋이 명소 거제 펜션 7곳
# 경북가볼만한곳 ♥경북풀빌라,울진풀빌라 어디가좋을까 고민중  온수풀 실내수영장펜션인  풀빌라블루아라로 결정▶ 만족할만한 울진숙소 발견♪ 경북드라이브코스 찾아 다녀온 멋진 경북여행
# 경주 키즈펜션 <키즈 플레이스> 풀빌라로 온전히 즐긴 하루
# 경주 키즈펜션 추천 루나힐풀빌라 에어바운스 룸
# [포항숙소] 포항펜션 데이토나 풀빌라 오션뷰 포항풀빌라 이용후기
# 제주도 독채 풀빌라 노을정원 펜션
# 경주 펜션 엘라포니시 풀빌라 오션뷰 환상적
# 가평 키즈풀빌라 펜션 아이캐슬키즈풀빌라 아이와가볼만한곳 추천
# 울산오션뷰펜션 히든베이풀빌라 미온수 수영장까지 완벽한 201호
# 키즈펜션추천 밀양 아주르 키즈풀빌라 (아기랑갈만한곳, 애들데리고갈만한곳)
# <여수여행> 역대급 오션뷰 맛집! 가성비 수영장 펜션 <더뷰917> 인생펜션 인생샷 추천!
# 꼭 다시 가고픈 경주 애견동반펜션 풀빌라숙소 헤이미쉬에서 행복한 꿀잠 여행! 꿈같은 강아지 수지와 함께
# 여수풀빌라 비고리조트 여수오션뷰펜션 수영장펜션 산책로까지 완벽했던곳
# 경주펜션 엘라포니시 풀빌라 오션뷰펜션
# 제주풀빌라 코롱코롱 야자수가 예쁜 야외온수수영장 커플풀빌라펜션❤️
# 대부도키즈풀빌라펜션 추천, 수까사
# 경주 애견동반펜션 / 오류고아라해변 부근 미온수 수영장 비치힐 풀빌라
# 가평 키즈풀빌라, 코코키즈펜션 역대급이다!
# 태안 가족풀빌라, 더마레풀빌라 생일기념으로 다녀왔어요~
# 가평 독채 키즈 실내외수영장 펜션 아이린 키즈풀빌라 (서울근교 아이랑 가볼만한곳)
# 경주 풀빌라 추천 미온수 수영장 여기 괜찮네!
# 가평 키즈 풀빌라 가족들과 가기 좋은 키즈펜션
# 여수 독채펜션 풀빌라 비고리조트 이슬라
# 가평 키즈펜션 라무키즈풀빌라 10인방문후기
# 대부도 키즈펜션 가볼만한곳 풀빌라라 안심 방아머리선착장 가깝네
# 청도 펜션 굿스파 키즈 풀빌라 매일 교체되는 온천수
# 제주 온수풀빌라 감성숙소는 누운에서 신년회
# 경주키즈풀빌라 공기좋은  휴휴키즈펜션추천
# 즐거웠던 경주펜션 경주풀빌라펜션 청담펜션
# 포항 펜션 영덕 가족 여행으로 좋은 풀빌라 감성숙소-하저스테이
# 경주 감성 펜션 / 경주 풀빌라 펜션 <마중펜션> 갬성 낭낭한 커플펜션으로 추천!
# 거제 키즈 풀빌라 레인보우펜션 가족 온수풀 씐나 ♬
# 아이들이 좋아하는 한옥 독채 키즈 풀빌라 펜션
# 경주 키즈풀빌라 온수풀로 푹 쉬다 온 후기
# 대부도 키즈풀빌라 황금바다 펜션 힐링하기 좋다
# 밀양 풀빌라 펜션 까사아미고에서 휴식하고 왔어요
# 밀양 키즈 풀빌라 아주르 펜션 아이들이 너무 신나해요
# 가평 남이섬 펜션, 리버노스 풀빌라 독채 키즈펜션추천해요!
# 포항 오션뷰 펜션  데이토나 풀빌라 힐링이야
# 가평키즈펜션 통통키즈풀빌라 아이와 가볼만한곳 추천 (개별놀이공간, 바베큐)
# 인천 대부도 티앤지 펜션 풀빌라 키즈 실내 온수 수영장 (신축 가족펜션 숙소)
# 경주 감포 풀빌라, 엘라포니시 펜션호텔 조식도 맛있어요♪
# 거제 풀빌라 펜션 비엘펜션
# 공현진 풀빌라 펜션 뷰가아름다운 라헨느J
# 경기도 가평애견풀빌라펜션 수영장, 바베큐, 땡큐도그펜션 가평숙소
# 춘천 남이섬 풀빌라 펜션 리버노스 가족여행~ (w.아이와가볼만한곳 추천)
# 가평 풀빌라 펜션 조카들 독채 온수수영장 프라이빗했던 BROOK 5
# 가평 풀빌라 보보펜션 스파와 수영장까지
# 가평키즈펜션 도도풀빌라 10번방 두번째 방문기
# 고성펜션 까사델아야 오션뷰 강원도 감성숙소
# 포항여행 미온수무료 포항풀빌라 어보브블루펜션
# 대전 근교 풀빌라 수영장과 독채로 조용한 감성숙소 전라도 무주 모모펜션
# 여수 스파펜션 - 까르마풀빌라펜션
# 거제도 펜션 거제 풀빌라 캄포하우스
# 제천펜션 풀빌라 수페23 충주호 단양펜션 천국이 따로 없네
# 태안가볼만한곳 스테이21, 감성숙소 독채펜션 태안풀빌라로 강추!
# 경주키즈풀빌라 온수풀 휴휴키즈풀빌라
# 대부도 유리섬펜션타운 아이와함께 키즈풀빌라펜션 다녀온 솔직후기
# 제주 한림 협재 라피아하우스 독채 풀빌라 펜션 2박 - 1일차 감성 불멍
# 거제 키즈풀빌라 오션뷰 온수풀이 그림같은 프라이빗상상
# 가평키즈풀빌라 독채라 더 좋은 키즈펜션 파파야키즈풀빌라
# 경주 감포 풀빌라 이오스풀빌라 오션뷰 프라이빗 숙소 A301호
# 가평 키즈펜션 : 미즈베베 키즈풀빌라 두번째 방문:)
# 남해 신혼여행 숙소 : 남해 풀빌라 더뷰1151 오션3(ocean3) 2박 후기
# 춘천 통창 펜션 피그멜리온이펙트 204호 대형욕조
# 청도 풀빌라 까사로마 | 온수풀 독채펜션 추천
# 포항 펜션 데이토나 풀빌라 인피니티풀과 전면 오션뷰라서 좋아!
# 거제도 키즈풀빌라 레인보우 펜션 거제
# 강릉 수영장펜션 이즈원풀빌라 / 루프탑 오션뷰 풀빌라
# 키즈펜션추천 서울근교 아인티오 풀빌라, 공동육아
# 제주도 독채 풀빌라 펜션, 서귀포 <코삿한하루>
# 가평 바니힐 키즈풀빌라! 여기가 바로 아이들 천국~
# 돌고래 뛰노는 해안가에서 즐기는 온수풀 제주도 풀빌라 제주 스테이데이앤데이
# 경주 키즈풀빌라 펜션 추천 독채라 편해 w. 아이놀자
# 밀양 키즈펜션 아주르 키즈풀빌라 주변 경관마저 힐링
# 송정 오션뷰로 즐기는 인피니트풀과 스파 부산 풀빌라 펜션
# 휴휴키즈풀빌라 :: 1박 2일 가족여행 / 아이와 함께 가볼만한 경주키즈풀빌라 가족펜션.
# 경기도 가평 풀빌라 가족여행 펜션 실내 개별수영장 노래방 키즈카페 놀이방 송어낚시무료
# 포항 풀빌라 펜션 제이나인풀빌라 솔찍후기 포항여행
# 고성 풀빌라 독채펜션 프라이빗 끝판왕!
# 대부도 풀빌라 키즈온수풀 깨끗했던 플레이스펜션
# 가평 키즈펜션 아이들 천국이네
# 울릉도 숙소 펠리체펜션 일출이 멋진 풀빌라
# 경주 펜션 추천 전객실 오션뷰 경주 숙소 비치힐 풀빌라
# 여수 온수풀 블루망고풀빌라 펜션, 이국적인 인피니티풀에 오션뷰까지!(이용 꿀팁)
# [경주_숙소추천]깔끔했던 페리토 애견풀빌라 펜션
# 가평 키즈풀빌라 펜션 : 아이캐슬키즈풀빌라 온수풀 + 놀이터 진심 추천
# 청도 풀빌라 펜션 대구 근교 펜션 엘라고
# [코끼리펜션_안산단원구] 대부도독채펜션 대부도풀빌라펜션 복층펜션
# [3박4일 남해여행] 남해숙소 │ 남해풀빌라 펜션 - 웨이포인트 P101 호
# 경남 가볼만한곳 사천 바다 가득한 풍경
# 영월 프레임하우스 비브릿지 풀빌라 펜션 또 갈거에요
# 경주키즈풀빌라 라파미키즈풀빌라 비 와도 걱정 없어 맘껏 놀자
# 여수 풀빌라 스파펜션 백야도 시로리조트
# 대부도 독채 풀빌라 펜션단지 미까사 대박재밌어
# 아이와 가을여행, 독채 키즈풀빌라 내돈내산 키즈펜션추천
# 여수 애견펜션 슈가브리움 애견동반 풀빌라 강아지와여행
# 경주펜션 더마린 풀빌라 경주 감포 애견 동반 가능한 테마파크 수준의 스파 펜션
# 가평 풀빌라펜션 리버노스 여유로운 휴식
# 2021 쥬디픽 국내 숙소 BEST 5 :: 일주일에 한 번은 외박했다
# 가평키즈펜션 안전하고 놀거리 많은 가평키즈풀빌라
# 1박2일 가족여행 우리만의 독채 펜션 여수 키즈풀빌라 뜨레놀레
# 경주 풀빌라 실내수영장이 있는 라인뷰펜션
# 가평 풀빌라 펜션, 브룩5 수영장 / 바베큐
# [남해여행] 남해여행 숙소 추천 '바다사랑 풀빌라 펜션' ::: 인피니티풀과 정원이 예쁜 펜션, 스노쿨링 가능
# 제주도 키즈풀빌라 아이와 찾기 좋은 제주여행 숙박
# 여수 슈가브리움 프라이빗 풀빌라 가족펜션
# 오늘도 가평키즈풀빌라 실내 개별수영장 독채펜션 아이랑 가볼만한 곳
# 청도 펜션, 굿스파키즈풀빌라
# 경주 키즈펜션 안하우스 온수 키즈 풀빌라 깔끔해서 가족여행하고 딱 좋아(담엔 조카랑같이)
# 양평 키즈풀빌라 경기 키즈펜션 / 빌리키즈풀빌라리조트 다녀오다
# 가평 키즈풀빌라펜션 아이캐슬키즈풀빌라
# 가평키즈펜션 우리가족 여행기 엘사키즈펜션
# 충북 제천 수페23 POOL02 프라이빗 풀빌라
# 프라이빗한 거제도 펜션 베스트 5
# 태안 키즈풀빌라 , 신축 쿠키키즈풀빌라 펜션 다녀왔어요
# 서울 근교 가평 아기랑갈만한곳 키즈펜션추천 리버노스풀빌라
# 양평 키즈풀빌라 펜션, 경기 아이와 가볼만한곳 w 빌리키즈풀빌라리조트
# [애견펜션/애견풀빌라]천국이 있다면 여길까 '경주 위클라드펜션' 내돈내산 후기
# 제주 구좌 풀빌라펜션 외국느낌 수영장 삼우요트빌리지 하룻밤~
# 가평 키즈펜션추천 도도키즈풀빌라 장난감 천국
# 가평키즈펜션추천! 아이가 행복한 미즈베베키즈풀빌라
# 가평키즈풀빌라 키즈펜션추천 가평 아이와 가볼만한 곳
# 경주 독채 풀빌라 펜션 신축에 유아풀까지
# 포항 하루풀빌라펜션, 오션뷰와 함께한 럭셔리 여행
# 포항 풀빌라 펜션 포에스 커플 여행 다녀왔어요.(일출, 일몰 OK)
# 여수 라테라스리조트 수영장, 오션스위트 풀빌라 감성 숙소 추천
# 무주 마리나풀빌라 펜션 온수풀이 대박
# 제주 풀빌라 펜션 '까르마',실내 온수풀있어 너무 좋아!
# 성주 아트빌리지 포천계곡 풀빌라 펜션
# 프라이빗한 에이요키즈풀빌라 포천 펜션 추천
# 가평 마리누스 풀빌라ㅣ넓고 깔끔한 독채 풀빌라 내돈내산 솔직후기
# 경주 풀빌라 수영장 펜션 없는게 없는 헤이미쉬!!
# 가평키즈풀빌라 실내온수수영장 아이린키즈펜션
# 가평 풀빌라펜션, 여우가 달을 사랑할때 솔직후기
# 포천 키즈펜션 어느 정도길래
# 아기랑 강화 풀빌라 펜션 :: 웨스트앤드빌
# 가평키즈풀빌라 아이와 갈만한 곳, 아이린키즈풀빌라 펜션
# 울산 풀빌라 히든베이 바다뷰 야외수영장 펜션
# 경주 인하트 풀빌라 키즈 펜션, 3가족 여행 솔직후기 (스파2, 시크릿1 )
# 강릉 펜션 풀빌라 여유롭게 즐기고 왔어요
# 제주 키즈풀빌라 선흘아이, 수영장까지 완벽한 독채키즈펜션
# 남해 풀빌라 숙소 격이 다른 독채 스테이빛토
# 아이랑 제주 동쪽 숙소 수영장 스파펜션 아르츠스파앤풀빌라 만족도!
# 가평키즈펜션 미즈베베키즈풀빌라 겨울에도 대만족
# [경북] 포항 풀빌라 펜션 추천, '씨앤뷰풀빌라' : 스위밍 스파와 월포해수욕장을 바로 앞 오션뷰가 인상적인 포항 숙소
# 경남 거제 펜션 로제스 풀빌라 ❥ 흥남해수욕장 바로 앞
# 경주 펜션 한옥 애견 동반 숙소 풀빌라 헤윰 내돈내산
# 경주 풀빌라 펜션  더마린 풀빌라 The Marine pool villa
# 부산 송정 풀빌라 펜션 : 기장 타이드어웨이
# 포항펜션추천 리틀포레스트 독채풀빌라 새로 오픈해서 좋아요
# 거제도 풀빌라 놀거리 가득한 퍼니펜션
# 가평 펜션 남이섬 설리조트 풀빌라 펜션 온수수영장 꿀잼
# 키즈펜션추천 가평키즈풀빌라 파파야키즈풀빌라 실내수영장 만족

# %%
print(len(titles))
print(len(main_contents))
print(len(place_ids))
print(len(place_names))
print(len(place_addrs))
print(len(place_tels))
print(len(lats))
print(len(lons))
print(len(urls))
print(len(blog_urls))
# Out:
# 442
# 442
# 442
# 442
# 442
# 442
# 442
# 442
# 442
# 442

# %% [markdown]
# * 크롤링한 데이터 데이터프레임으로 변환

# %%
blog_df = pd.DataFrame()

blog_df['titles'] = titles
blog_df['main_contents'] = main_contents
blog_df['place_ids'] = place_ids
blog_df['place_names'] = place_names
blog_df['place_addrs'] = place_addrs
blog_df['place_tels'] = place_tels
blog_df['lats'] = lats
blog_df['lons'] = lons
blog_df['urls'] = urls
blog_df['blog_urls'] = blog_urls

# %% [markdown]
# * search_blogs와 merge해서 최종 데이터 프레임 생성

# %%
result_df = pd.merge(blog_df, search_blogs, on='urls', how='left')
result_df.head()
# Out:
#                                        titles  \
# 0                   경남 펜션 오션뷰 숙소 사천 풀빌라 독채 펜션
# 1                      부산 펜션 송정해수욕장 풀빌라 호텔 후기
# 2  남해 숙소 추천 감성 오션뷰 수영장 노천탕 남해 풀빌라 펜션 웨이포인트풀빌라
# 3                    경남 펜션 감성 넘치는 사천 풀빌라 독채펜션
# 4                   대부도 풀빌라 디디모스 키즈 펜션 리얼 후기
#
#                                        main_contents   place_ids  \
# 0  경남 펜션 오션뷰 숙소 사천 풀빌라 독채 펜션 펜캉스 힐링 경남 독채펜션~\n11월...
# 1  Busan - 온수풀 풀빌라 있는데 가성비 좋은 숙소 - 올해는 곳곳에 화이트 크리...  1102393804
# 2  제가 가장 좋아하는 여행지 중 한곳이 바로 남해에요!! 남해안 도로를 따라 드라이브...  1172720598
# 3  경남 펜션 사천 풀빌라\n토끼와 거북이의 이야기가 있는 사천 비토섬으로 2박 3일 ...    32779463
# 4  겨울이 코 앞으로 다가오면서 가족들을 위한 온수 풀장이 있는 펜션을 찾는 분들이 많...  1109160883
#
#        place_names                              place_addrs      place_tels  \
# 0      사천리조트 풀빌라펜션                경상남도 사천시 토끼로 245 비토섬신우리조트            None
# 1     그레이샌즈 풀빌라 펜션  부산광역시 해운대구 송정해변로 30-1 그레이샌즈 2층 3층 4층 5층   010-4074-0790
# 2        웨이포인트 풀빌라                 경상남도 남해군 서면 남서대로 1803-64   010-8836-1388
# 3  비토섬 신우리조트N풀빌라펜션                   경상남도 사천시 서포면 토끼로 245-5  0507-1497-4244
# 4           디디모스펜션                  경기도 안산시 단원구 부흥로 287-292   010-5205-6393
#
#          lats         lons                                               urls  \
# 0  34.9844337  127.9663409  https://in.naver.com/jbm993/contents/internal/...
# 1  35.1809217   129.202743  https://in.naver.com/mango/contents/internal/3...
# 2   34.818569  127.8266747  https://in.naver.com/rafiuta/contents/internal...
# 3  34.9844333  127.9663639  https://in.naver.com/tcacyc/contents/internal/...
# 4  37.2208471  126.6051739  https://in.naver.com/usgreen99/contents/intern...
#
#                                            blog_urls      dates bloger_names  \
# 0  https://blog.naver.com/jbm993/222606263670?isI... 2021-12-27          열씨미
# 1  https://blog.naver.com/foresten/222603948009?i... 2021-12-24         망고요정
# 2  https://blog.naver.com/rafiuta/222602217417?is... 2021-12-23           유에
# 3  https://blog.naver.com/tcacyc/222584628097?isI... 2021-12-02         일상탈출
# 4  https://blog.naver.com/usgreen99/222574303564?... 2021-11-21          에릭샘
#
#     fans  year  month  day
# 0  14000  2021     12   27
# 1  13000  2021     12   24
# 2   1000  2021     12   23
# 3  13000  2021     12    2
# 4  11000  2021     11   21

# %% [markdown]
# * csv 파일로 저장

# %%
## pension 데이터 csv 파일로 저장
result_df.to_csv('pension_pool.csv', index = False, encoding='utf-8')

#검색어 확인하고 pension_뒷부분 바꿔주세요! ★

# %% [markdown]
# ## 2. 데이터 정제

# %%
pension_couple = pd.read_csv("pension_couple.csv", encoding='utf-8')
pension_dog = pd.read_csv("pension_dog.csv", encoding='utf-8')
pension_family = pd.read_csv("pension_family.csv", encoding='utf-8')
pension_kids = pd.read_csv("pension_kids.csv", encoding='utf-8')
pension_nokids = pd.read_csv("pension_nokids.csv", encoding='utf-8')
pension_ocean = pd.read_csv("pension_ocean.csv", encoding='utf-8')
pension_pool = pd.read_csv("pension_pool.csv", encoding='utf-8')
pension_spa = pd.read_csv("pension_spa.csv", encoding='utf-8')

# %%
pension_couple['type'] = 'cpl'
pension_dog['type'] = 'dog'
pension_family['type'] = 'fmly'
pension_kids['type'] = 'kids'
pension_nokids['type'] = 'nokids'
pension_ocean['type'] = 'ocean'
pension_pool['type'] = 'pool'
pension_spa['type'] = 'spa'

# %%
print(pension_couple.shape)
print(pension_dog.shape)
print(pension_family.shape)
print(pension_kids.shape)
print(pension_nokids.shape)
print(pension_ocean.shape)
print(pension_pool.shape)
print(pension_spa.shape)
# Out:
# (362, 17)
# (350, 17)
# (436, 17)
# (301, 17)
# (89, 17)
# (440, 17)
# (442, 17)
# (413, 17)

# %%
362+350+436+301+89+440+442+413
# Out:
# 2833

# %%
pension_list = [pension_couple, pension_dog, pension_family, pension_kids, pension_nokids, pension_ocean, pension_pool, pension_spa]
pension_df = pd.concat(pension_list, ignore_index=True)

pension_df.shape
# Out:
# (2833, 17)

# %% [markdown]
# * year, month, day 컬럼 추가

# %%
pension_df['year'] = pension_df['dates'].dt.year
pension_df['month'] = pension_df['dates'].dt.month
pension_df['day'] = pension_df['dates'].dt.day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19940/127238154.py in <module>
# ----> 1 blog_df['year'] = blog_df['dates'].dt.year
#       2 blog_df['month'] = blog_df['dates'].dt.month
#       3 blog_df['day'] = blog_df['dates'].dt.day
#
# NameError: name 'blog_df' is not defined

# %%
pension_df['season'] = 'season'

pension_df['season'][pension_df['month']==12] = 'win'   #겨울
pension_df['season'][pension_df['month']==1] = 'win'
pension_df['season'][pension_df['month']==2] = 'win'
pension_df['season'][pension_df['month']==3] = 'spr'   #봄
pension_df['season'][pension_df['month']==4] = 'spr'
pension_df['season'][pension_df['month']==5] = 'spr'
pension_df['season'][pension_df['month']==6] = 'sum'   #여름
pension_df['season'][pension_df['month']==7] = 'sum'
pension_df['season'][pension_df['month']==8] = 'sum'
pension_df['season'][pension_df['month']==9] = 'aut'   #가을
pension_df['season'][pension_df['month']==10] = 'aut'
pension_df['season'][pension_df['month']==11] = 'aut'

pension_df['season'].head()
# Out:
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==12] = 'win'   #겨울
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==1] = 'win'
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==2] = 'win'
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==3] = 'spr'   #봄
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==4] = 'spr'
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==5] = 'spr'
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==6] = 'sum'   #여름
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==7] = 'sum'
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==8] = 'sum'
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==9] = 'aut'   #가을
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==10] = 'aut'
# C:\Users\dhfps\AppData\Local\Temp/ipykernel_19940/2380678841.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pension_df['season'][pension_df['month']==11] = 'aut'
# 0    win
# 1    aut
# 2    aut
# 3    win
# 4    win
# Name: season, dtype: object

# %% [markdown]
# ### 결측값 확인 및 처리

# %%
pension_df.info()     #place_ids, place_tels만 결측치 존재
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2833 entries, 0 to 2832
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   titles         2833 non-null   object
#  1   main_contents  2833 non-null   object
#  2   place_ids      2791 non-null   float64
#  3   place_names    2833 non-null   object
#  4   place_addrs    2833 non-null   object
#  5   place_tels     2664 non-null   object
#  6   lats           2833 non-null   float64
#  7   lons           2833 non-null   float64
#  8   urls           2833 non-null   object
#  9   blog_urls      2833 non-null   object
#  10  dates          2833 non-null   object
#  11  bloger_names   2833 non-null   object
#  12  fans           2833 non-null   int64
#  13  year           2833 non-null   int64
#  14  month          2833 non-null   int64
#  15  day            2833 non-null   int64
#  16  type           2833 non-null   object
#  17  season         2833 non-null   object
# dtypes: float64(3), int64(4), object(11)
# memory usage: 398.5+ KB

# %%
pension_df = pension_df.fillna(0)     #결측치 모두 0으로 대체

# %%
pension_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2833 entries, 0 to 2832
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   titles         2833 non-null   object
#  1   main_contents  2833 non-null   object
#  2   place_ids      2833 non-null   float64
#  3   place_names    2833 non-null   object
#  4   place_addrs    2833 non-null   object
#  5   place_tels     2833 non-null   object
#  6   lats           2833 non-null   float64
#  7   lons           2833 non-null   float64
#  8   urls           2833 non-null   object
#  9   blog_urls      2833 non-null   object
#  10  dates          2833 non-null   object
#  11  bloger_names   2833 non-null   object
#  12  fans           2833 non-null   int64
#  13  year           2833 non-null   int64
#  14  month          2833 non-null   int64
#  15  day            2833 non-null   int64
#  16  type           2833 non-null   object
#  17  season         2833 non-null   object
# dtypes: float64(3), int64(4), object(11)
# memory usage: 398.5+ KB

# %%
## pension_df csv 파일로 저장
pension_df.to_csv('pension_df.csv', index = False, encoding='utf-8')

# %%
## pension_df 파일 불러오기
pension_df = pd.read_csv("pension_df.csv", encoding='utf-8')

# %% [markdown]
# ### 2021년만 사용

# %%
## 2021년 데이터만 슬라이싱

pension_2021 = pension_df[pension_df['year']==2021]
pension_2021.head()
# Out:
#                                               titles  \
# 0        제주도 커플펜션 추천/ 제주N스테이, 바다가 보이는 예쁜 공간에서 하루를...
# 1                         제주 커플펜션 오션뷰 뷰스팟 제주도 서쪽 숙소
# 2                             제주 오션뷰 멋진 제주도 커플 펜션 숙소
# 3  경주 스파펜션 / 울산 스파펜션 <러브앤러브 펜션> #커플펜션 #내돈주고 다녀온 솔...
# 4  가평 커플 펜션 숙소 추천 라스블랑카스(LAS BLANCAS) 펜션 숙박 이용 리얼 후기
#
#                                        main_contents     place_ids  \
# 0  제주도 커플펜션 추천/ 제주N스테이 언제라도 갈대마다 마음이 편안해지고 즐거워지는 ...  1.467548e+09
# 1  제주 커플펜션 오션뷰 뷰스팟 제주도 서쪽 숙소 제주도 서쪽 숙소 저바다에 누워~\n...  1.079993e+09
# 2  가을 제주가 너무 아름다워 아주 짧게 와이프와 제주도를 다시 다녀왔습니다. 1박 2...  1.347007e+09
# 3  안녕하세요~\n오늘은 #경주오션힐스 펜션촌에 위치한\n#러브앤러브펜션 포스팅을 해볼...  3.080236e+07
# 4  추억의 한자리를 차지하고 있는 가평 대성리 MT촌 펜션에서 하룻밤 숙박을 하고 왔습...  7.786633e+08
#
#   place_names                    place_addrs      place_tels       lats  \
# 0      제주N스테이    제주특별자치도 제주시 구좌읍 한동북1길 60 C동  0507-1324-0978  33.542778
# 1      저바다에누워        제주특별자치도 제주시 한경면 판조로 3-5  0507-1440-7904  33.367228
# 2      저바다에누워        제주특별자치도 제주시 한경면 판조로 3-5               0  33.367236
# 3       러브앤러브           경상북도 경주시 양남면 솔숲3길 18  0503-5058-2619  35.664785
# 4      라스블랑카스  경기도 가평군 청평면 남이터길 54-12 라스블랑카스   010-8569-3340  37.689413
#
#          lons                                               urls  \
# 0  126.830518  https://in.naver.com/gagamal740718/contents/in...
# 1  126.205140  https://in.naver.com/jbm993/contents/internal/...
# 2  126.205129  https://in.naver.com/ultraorange/contents/inte...
# 3  129.406206  https://in.naver.com/yt___26/contents/internal...
# 4  127.371586  https://in.naver.com/pilyo93/contents/internal...
#
#                                            blog_urls  \
# 0  https://blog.naver.com/gagamal740718/222608098...
# 1  https://blog.naver.com/jbm993/222554609062?isI...
# 2  https://blog.naver.com/lightsout/222550520526?...
# 3  https://blog.naver.com/ysnjhfav/222585304055?i...
# 4  https://blog.naver.com/pilyo93/222595781807?is...
#
#                         dates bloger_names   fans  year  month  day type  \
# 0  2021-12-30 16:46:59.995526   꼬미의 제주도 여행   1128  2021     12   30  cpl
# 1  2021-10-31 00:00:00.000000          열씨미  14000  2021     10   31  cpl
# 2  2021-10-27 00:00:00.000000       울트라오렌지  15000  2021     10   27  cpl
# 3  2021-12-02 00:00:00.000000          체로미   2011  2021     12    2  cpl
# 4  2021-12-15 00:00:00.000000      맛집여행이정표    368  2021     12   15  cpl
#
#   season
# 0    win
# 1    aut
# 2    aut
# 3    win
# 4    win

# %% [markdown]
# ### 팬 수별로 level col 생성

# %%
pension_2021['level'] = 0

for i in range(len(pension_2021)):
    
    if pension_2021['fans'][i] < 2500:
        pension_2021.loc[i,'level'] = 1
    elif pension_2021['fans'][i] < 5000:
        pension_2021.loc[i,'level'] = 2
    elif pension_2021['fans'][i] < 10000:
        pension_2021.loc[i,'level'] = 3
    else:
        pension_2021.loc[i,'level'] = 4

pension_2021['level'].head()
# Out:
# 0    1
# 1    4
# 2    4
# 3    1
# 4    1
# Name: level, dtype: int64

# %%
pension_2021['fans'].head()
# Out:
# 0     1128
# 1    14000
# 2    15000
# 3     2011
# 4      368
# Name: fans, dtype: int64

# %% [markdown]
# ### 펜션 시도 col 생성

# %%
for i in range(len(pension_2021)):
    index = pension_2021.loc[i,'place_addrs'].find(" ")
    pension_2021.loc[i,'geo'] = pension_2021.loc[i,'place_addrs'][:index]
    
pension_2021.head()
# Out:
#                                               titles  \
# 0        제주도 커플펜션 추천/ 제주N스테이, 바다가 보이는 예쁜 공간에서 하루를...
# 1                         제주 커플펜션 오션뷰 뷰스팟 제주도 서쪽 숙소
# 2                             제주 오션뷰 멋진 제주도 커플 펜션 숙소
# 3  경주 스파펜션 / 울산 스파펜션 <러브앤러브 펜션> #커플펜션 #내돈주고 다녀온 솔...
# 4  가평 커플 펜션 숙소 추천 라스블랑카스(LAS BLANCAS) 펜션 숙박 이용 리얼 후기
#
#                                        main_contents     place_ids  \
# 0  제주도 커플펜션 추천/ 제주N스테이 언제라도 갈대마다 마음이 편안해지고 즐거워지는 ...  1.467548e+09
# 1  제주 커플펜션 오션뷰 뷰스팟 제주도 서쪽 숙소 제주도 서쪽 숙소 저바다에 누워~\n...  1.079993e+09
# 2  가을 제주가 너무 아름다워 아주 짧게 와이프와 제주도를 다시 다녀왔습니다. 1박 2...  1.347007e+09
# 3  안녕하세요~\n오늘은 #경주오션힐스 펜션촌에 위치한\n#러브앤러브펜션 포스팅을 해볼...  3.080236e+07
# 4  추억의 한자리를 차지하고 있는 가평 대성리 MT촌 펜션에서 하룻밤 숙박을 하고 왔습...  7.786633e+08
#
#   place_names                    place_addrs      place_tels       lats  \
# 0      제주N스테이    제주특별자치도 제주시 구좌읍 한동북1길 60 C동  0507-1324-0978  33.542778
# 1      저바다에누워        제주특별자치도 제주시 한경면 판조로 3-5  0507-1440-7904  33.367228
# 2      저바다에누워        제주특별자치도 제주시 한경면 판조로 3-5               0  33.367236
# 3       러브앤러브           경상북도 경주시 양남면 솔숲3길 18  0503-5058-2619  35.664785
# 4      라스블랑카스  경기도 가평군 청평면 남이터길 54-12 라스블랑카스   010-8569-3340  37.689413
#
#          lons                                               urls  \
# 0  126.830518  https://in.naver.com/gagamal740718/contents/in...
# 1  126.205140  https://in.naver.com/jbm993/contents/internal/...
# 2  126.205129  https://in.naver.com/ultraorange/contents/inte...
# 3  129.406206  https://in.naver.com/yt___26/contents/internal...
# 4  127.371586  https://in.naver.com/pilyo93/contents/internal...
#
#                                            blog_urls  \
# 0  https://blog.naver.com/gagamal740718/222608098...
# 1  https://blog.naver.com/jbm993/222554609062?isI...
# 2  https://blog.naver.com/lightsout/222550520526?...
# 3  https://blog.naver.com/ysnjhfav/222585304055?i...
# 4  https://blog.naver.com/pilyo93/222595781807?is...
#
#                         dates bloger_names   fans  year  month  day type  \
# 0  2021-12-30 16:46:59.995526   꼬미의 제주도 여행   1128  2021     12   30  cpl
# 1  2021-10-31 00:00:00.000000          열씨미  14000  2021     10   31  cpl
# 2  2021-10-27 00:00:00.000000       울트라오렌지  15000  2021     10   27  cpl
# 3  2021-12-02 00:00:00.000000          체로미   2011  2021     12    2  cpl
# 4  2021-12-15 00:00:00.000000      맛집여행이정표    368  2021     12   15  cpl
#
#   season  level      geo
# 0    win      1  제주특별자치도
# 1    aut      4  제주특별자치도
# 2    aut      4  제주특별자치도
# 3    win      1     경상북도
# 4    win      1      경기도

# %%
## pension_2021 csv 파일로 저장
pension_2021.to_csv('pension_2021_new.csv', index = False, encoding='utf-8')

# %%
## pension_2021 파일 불러오기
pension_2021 = pd.read_csv("pension_2021.csv", encoding='utf-8')

# %% [markdown]
# ## 시각화 위한 mini df 생성

# %%
## 시도별 게시글 수

pension_div = pd.DataFrame(pension_2021['geo'].value_counts())
pension_div.reset_index(level=0, inplace=True)
pension_div.rename(columns = {'index' : 'ctp_name'}, inplace = True)
pension_div.rename(columns = {'geo' : 'post_count'}, inplace = True)
pension_div
# Out:
#    ctp_name  post_count
# 0       경기도         375
# 1      경상북도         342
# 2      경상남도         311
# 3       강원도         293
# 4   제주특별자치도         227
# 5      전라남도         153
# 6      충청남도         119
# 7     인천광역시          81
# 8     부산광역시          30
# 9      충청북도          27
# 10    울산광역시          23
# 11     전라북도          23
# 12    서울특별시           2
# 13  세종특별자치시           1
# 14    대구광역시           1

# %%
## 월별 게시글 수

pension_month = pd.DataFrame(pension_2021['month'].value_counts())
pension_month.reset_index(level=0, inplace=True)
pension_month.rename(columns = {'month' : 'post_count'}, inplace = True)
pension_month.rename(columns = {'index' : 'month'}, inplace = True)
pension_month
# Out:
#     month  post_count
# 0      12         356
# 1      11         312
# 2      10         228
# 3       7         165
# 4       6         164
# 5       9         152
# 6       5         147
# 7       8         139
# 8       4         121
# 9       3         104
# 10      1          70
# 11      2          50

# %%
## 펜션 타입별 게시글 수

pension_type = pd.DataFrame(pension_2021['type'].value_counts())
pension_type.reset_index(level=0, inplace=True)
pension_type.rename(columns = {'type' : 'post_count'}, inplace = True)
pension_type.rename(columns = {'index' : 'type'}, inplace = True)
pension_type
# Out:
#      type  post_count
# 0    pool         371
# 1   ocean         334
# 2    fmly         304
# 3     spa         291
# 4     dog         257
# 5    kids         250
# 6     cpl         157
# 7  nokids          44

# %%
## 계절별 게시글 수

pension_season = pd.DataFrame(pension_2021['season'].value_counts())
pension_season.reset_index(level=0, inplace=True)
pension_season.rename(columns = {'season' : 'post_count'}, inplace = True)
pension_season.rename(columns = {'index' : 'season'}, inplace = True)
pension_season
# Out:
#   season  post_count
# 0    aut         692
# 1    win         476
# 2    sum         468
# 3    spr         372

# %%
## pension_div csv 파일로 저장
pension_div.to_csv('pension_div.csv', index = False, encoding='utf-8')

# %%
## pension_month csv 파일로 저장
pension_month.to_csv('pension_month.csv', index = False, encoding='utf-8')

# %%
## pension_type csv 파일로 저장
pension_type.to_csv('pension_type.csv', index = False, encoding='utf-8')

# %%
## pension_season csv 파일로 저장
pension_season.to_csv('pension_season.csv', index = False, encoding='utf-8')

# %%
## 월, 타입, 계절, 시도별 게시글 수 그룹 df 생성

group = pension_2021.groupby(["month","type","season","geo"])
p_group = group.size().reset_index(name='post_count')

p_group
# Out:
#      month type season      geo  post_count
# 0        1  cpl    win      강원도           1
# 1        1  cpl    win     경상남도           1
# 2        1  cpl    win     경상북도           1
# 3        1  cpl    win    인천광역시           1
# 4        1  cpl    win  제주특별자치도           1
# ..     ...  ...    ...      ...         ...
# 612     12  spa    win     경상남도           5
# 613     12  spa    win     경상북도           4
# 614     12  spa    win    인천광역시           3
# 615     12  spa    win     전라남도           1
# 616     12  spa    win     전라북도           1
#
# [617 rows x 5 columns]

# %%
## p_group csv 파일로 저장
p_group.to_csv('p_group.csv', index = False, encoding='utf-8')
